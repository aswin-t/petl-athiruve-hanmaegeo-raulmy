# %% [markdown]
# <a href="https://colab.research.google.com/github/aswin-t/petl-athiruve-hanmaegeo-raulmy/blob/main/notebooks/glue_text_to_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Imports

# %%
# !pip install datasets --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 23.7 MB/s eta 0:00:00

# %%
# !pip install huggingface_hub --quiet

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from datasets import load_dataset, Dataset
import pandas as pd

# %% [markdown]
# ## COLA Dataset
#
# The Corpus of Linguistic Acceptability consists of English acceptability judgments drawn from books and journal articles on linguistic theory. Each example is a sequence of words annotated with whether it is a grammatical English sentence.

# %%
cola_dataset = load_dataset('glue', 'cola')
# Out:
# ...
# Generating test split:   0%|          | 0/1063 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/cola/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
inputs = []
splits = []
targets = []

for split_label in ['train', 'test', 'validation']:
  split = cola_dataset[split_label]
  for i in range(len(split)):
    this_entry = split[i]
    this_input = f"sentence: {this_entry['sentence']}"
    this_target = 'test' if split_label == 'test' else 'acceptable' if this_entry['label'] == 1 else 'unacceptable'
    inputs.append(this_input)
    splits.append(split_label)
    targets.append(this_target)

cola_df = pd.DataFrame({
    'task': 'cola',
    'split': splits,
    'input': inputs,
    'target': targets,
})

# %%
cola_df.head()
# Out:
#    task  split                                              input      target
# 0  cola  train  sentence: Our friends won't buy this analysis,...  acceptable
# 1  cola  train  sentence: One more pseudo generalization and I...  acceptable
# 2  cola  train  sentence: One more pseudo generalization or I'...  acceptable
# 3  cola  train  sentence: The more we study verbs, the crazier...  acceptable
# 4  cola  train  sentence: Day by day the facts are getting mur...  acceptable

# %% [markdown]
# ## SST2 Dataset
#
# The Stanford Sentiment Treebank consists of sentences from movie reviews and human annotations of their sentiment. The task is to predict the sentiment of a given sentence. It uses the two-way (positive/negative) class split, with only sentence-level labels.

# %%
sst2_dataset = load_dataset('glue', 'sst2')
# Out:
# ...
# Generating test split:   0%|          | 0/1821 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
inputs = []
splits = []
targets = []

for split_label in ['train', 'test', 'validation']:
  split = sst2_dataset[split_label]
  for i in range(len(split)):
    this_entry = split[i]
    this_input = f"review: {this_entry['sentence']}"
    this_target = 'test' if split_label == 'test' else 'positive' if this_entry['label'] == 1 else 'negative'
    inputs.append(this_input)
    splits.append(split_label)
    targets.append(this_target)

sst2_df = pd.DataFrame({
    'task': 'sst2',
    'split': splits,
    'input': inputs,
    'target': targets,
})

# %%
sst2_df.head()
# Out:
#    task  split                                              input    target
# 0  sst2  train  review: hide new secretions from the parental ...  negative
# 1  sst2  train       review: contains no wit , only labored gags   negative
# 2  sst2  train  review: that loves its characters and communic...  positive
# 3  sst2  train  review: remains utterly satisfied to remain th...  negative
# 4  sst2  train  review: on the worst revenge-of-the-nerds clic...  negative

# %% [markdown]
# ## MRPC Dataset
#
# The Microsoft Research Paraphrase Corpus (Dolan & Brockett, 2005) is a corpus of sentence pairs automatically extracted from online news sources, with human annotations for whether the sentences in the pair are semantically equivalent.

# %%
mrpc_dataset = load_dataset('glue', 'mrpc')
# Out:
# ...
# Generating test split:   0%|          | 0/1725 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/mrpc/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
inputs = []
splits = []
targets = []

for split_label in ['train', 'test', 'validation']:
  split = mrpc_dataset[split_label]
  for i in range(len(split)):
    this_entry = split[i]
    this_input = f"sentence1: {this_entry['sentence1']} sentence2: {this_entry['sentence2']}"
    this_target = 'equivalent' if this_entry['label'] == 1 else 'not equivalent'
    inputs.append(this_input)
    splits.append(split_label)
    targets.append(this_target)

mrpc_df = pd.DataFrame({
    'task': 'mrpc',
    'split': splits,
    'input': inputs,
    'target': targets,
})

# %%
mrpc_df.head()
# Out:
#    task  split                                              input  \
# 0  mrpc  train  sentence1: Amrozi accused his brother , whom h...
# 1  mrpc  train  sentence1: Yucaipa owned Dominick 's before se...
# 2  mrpc  train  sentence1: They had published an advertisement...
# 3  mrpc  train  sentence1: Around 0335 GMT , Tab shares were u...
# 4  mrpc  train  sentence1: The stock rose $ 2.11 , or about 11...
#
#            target
# 0      equivalent
# 1  not equivalent
# 2      equivalent
# 3  not equivalent
# 4      equivalent

# %% [markdown]
# ## QQP Dataset
#
# The Quora Question Pairs2 dataset is a collection of question pairs from the community question-answering website Quora. The task is to determine whether a pair of questions are semantically equivalent.

# %%
qqp_dataset = load_dataset('glue', 'qqp')
# Out:
# ...
# Generating test split:   0%|          | 0/390965 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/qqp/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
inputs = []
splits = []
targets = []

for split_label in ['train', 'test', 'validation']:
  split = qqp_dataset[split_label]
  for i in range(len(split)):
    this_entry = split[i]
    this_input = f"question1: {this_entry['question1']} question2: {this_entry['question2']}"
    this_target = 'test' if split_label == 'test' else 'duplicate' if this_entry['label'] == 1 else 'not duplicate'
    inputs.append(this_input)
    splits.append(split_label)
    targets.append(this_target)

qqp_df = pd.DataFrame({
    'task': 'qqp',
    'split': splits,
    'input': inputs,
    'target': targets,
})

# %%
qqp_df.head()
# Out:
#   task  split                                              input  \
# 0  qqp  train  question1: How is the life of a math student? ...
# 1  qqp  train  question1: How do I control my horny emotions?...
# 2  qqp  train  question1: What causes stool color to change t...
# 3  qqp  train  question1: What can one do after MBBS? questio...
# 4  qqp  train  question1: Where can I find a power outlet for...
#
#           target
# 0  not duplicate
# 1      duplicate
# 2  not duplicate
# 3      duplicate
# 4  not duplicate

# %% [markdown]
# ## STSB Dataset
#
# The Semantic Textual Similarity Benchmark (Cer et al., 2017) is a collection of sentence pairs drawn from news headlines, video and image captions, and natural language inference data. Each pair is human-annotated with a similarity score from 1 to 5.

# %%
stsb_dataset = load_dataset('glue', 'stsb')
# Out:
# ...
# Generating test split:   0%|          | 0/1379 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/stsb/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
inputs = []
splits = []
targets = []

for split_label in ['train', 'test', 'validation']:
  split = stsb_dataset[split_label]
  for i in range(len(split)):
    this_entry = split[i]
    this_input = f"sentence1: {this_entry['sentence1']} sentence2: {this_entry['sentence2']}"
    this_target = 'test' if split_label == 'test' else 'not similar' if this_entry['label'] < 1.5 else 'somewhat similar' if this_entry['label'] < 3.5 else 'similar'
    inputs.append(this_input)
    splits.append(split_label)
    targets.append(this_target)

stsb_df = pd.DataFrame({
    'task': 'stsb',
    'split': splits,
    'input': inputs,
    'target': targets,
})

# %%
stsb_df.head()
# Out:
#    task  split                                              input  \
# 0  stsb  train  sentence1: A plane is taking off. sentence2: A...
# 1  stsb  train  sentence1: A man is playing a large flute. sen...
# 2  stsb  train  sentence1: A man is spreading shreded cheese o...
# 3  stsb  train  sentence1: Three men are playing chess. senten...
# 4  stsb  train  sentence1: A man is playing the cello. sentenc...
#
#              target
# 0           similar
# 1           similar
# 2           similar
# 3  somewhat similar
# 4           similar

# %% [markdown]
# ## MNLI Dataset
#
# The Multi-Genre Natural Language Inference Corpus is a crowdsourced collection of sentence pairs with textual entailment annotations. Given a premise sentence and a hypothesis sentence, the task is to predict whether the premise entails the hypothesis (entailment), contradicts the hypothesis (contradiction), or neither (neutral). The premise sentences are gathered from ten different sources, including transcribed speech, fiction, and government reports. The authors of the benchmark use the standard test set, for which they obtained private labels from the RTE authors, and evaluate on both the matched (in-domain) and mismatched (cross-domain) section. They also uses and recommend the SNLI corpus as 550k examples of auxiliary training data.

# %%
mnli_dataset = load_dataset('glue', 'mnli')
# Out:
# ...
# Generating test_mismatched split:   0%|          | 0/9847 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/mnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
inputs = []
splits = []
targets = []

for split_label in ['train', 'test_matched', 'test_mismatched', 'validation_matched', 'validation_mismatched']:
  split = mnli_dataset[split_label]
  for i in range(len(split)):
    this_entry = split[i]
    this_input = f"premise: {this_entry['premise']} hypothesis: {this_entry['hypothesis']}"
    this_target = 'test' if split_label in ['test_matched', 'test_mismatched'] else 'entailment' if this_entry['label'] == 0 else 'contradiction' if this_entry['label'] == 2 else 'neutral'
    inputs.append(this_input)
    splits.append(split_label)
    targets.append(this_target)

mnli_df = pd.DataFrame({
    'task': 'mnli',
    'split': splits,
    'input': inputs,
    'target': targets,
})

# %%
mnli_df.head()
# Out:
#    task  split                                              input      target
# 0  mnli  train  premise: Conceptually cream skimming has two b...     neutral
# 1  mnli  train  premise: you know during the season and i gues...  entailment
# 2  mnli  train  premise: One of our number will carry out your...  entailment
# 3  mnli  train  premise: How do you know? All this is their in...  entailment
# 4  mnli  train  premise: yeah i tell you what though if you go...     neutral

# %% [markdown]
# ## QNLI Dataset
#
# The Stanford Question Answering Dataset is a question-answering dataset consisting of question-paragraph pairs, where one of the sentences in the paragraph (drawn from Wikipedia) contains the answer to the corresponding question (written by an annotator). The authors of the benchmark convert the task into sentence pair classification by forming a pair between each question and each sentence in the corresponding context, and filtering out pairs with low lexical overlap between the question and the context sentence. The task is to determine whether the context sentence contains the answer to the question. This modified version of the original task removes the requirement that the model select the exact answer, but also removes the simplifying assumptions that the answer is always present in the input and that lexical overlap is a reliable cue.

# %%
qnli_dataset = load_dataset('glue', 'qnli')
# Out:
# ...
# Generating test split:   0%|          | 0/5463 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/qnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
inputs = []
splits = []
targets = []

for split_label in ['train', 'test', 'validation']:
  split = qnli_dataset[split_label]
  for i in range(len(split)):
    this_entry = split[i]
    this_input = f"question: {this_entry['question']} sentence: {this_entry['sentence']}"
    this_target = 'test' if split_label == 'test' else 'entailment' if this_entry['label'] == 0 else 'not entailment'
    inputs.append(this_input)
    splits.append(split_label)
    targets.append(this_target)

qnli_df = pd.DataFrame({
    'task': 'qnli',
    'split': splits,
    'input': inputs,
    'target': targets,
})

# %%
qnli_df.head()
# Out:
#    task  split                                              input  \
# 0  qnli  train  question: When did the third Digimon series be...
# 1  qnli  train  question: Which missile batteries often have i...
# 2  qnli  train  question: What two things does Popper argue Ta...
# 3  qnli  train  question: What is the name of the village 9 mi...
# 4  qnli  train  question: What famous palace is located in Lon...
#
#            target
# 0  not entailment
# 1  not entailment
# 2      entailment
# 3      entailment
# 4  not entailment

# %% [markdown]
# ## RTE Dataset
#
# The Recognizing Textual Entailment (RTE) datasets come from a series of annual textual entailment challenges. The authors of the benchmark combined the data from RTE1 (Dagan et al., 2006), RTE2 (Bar Haim et al., 2006), RTE3 (Giampiccolo et al., 2007), and RTE5 (Bentivogli et al., 2009). Examples are constructed based on news and Wikipedia text. The authors of the benchmark convert all datasets to a two-class split, where for three-class datasets they collapse neutral and contradiction into not entailment, for consistency.

# %%
rte_dataset = load_dataset('glue', 'rte')
# Out:
# ...
# Generating test split:   0%|          | 0/3000 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/rte/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
inputs = []
splits = []
targets = []

for split_label in ['train', 'test', 'validation']:
  split = rte_dataset[split_label]
  for i in range(len(split)):
    this_entry = split[i]
    this_input = f"sentence1: {this_entry['sentence1']} sentence2: {this_entry['sentence2']}"
    this_target = 'test' if split_label == 'test' else 'entailment' if this_entry['label'] == 0 else 'not entailment'
    inputs.append(this_input)
    splits.append(split_label)
    targets.append(this_target)

rte_df = pd.DataFrame({
    'task': 'rte',
    'split': splits,
    'input': inputs,
    'target': targets,
})

# %%
rte_df.head()
# Out:
#   task  split                                              input  \
# 0  rte  train  sentence1: No Weapons of Mass Destruction Foun...
# 1  rte  train  sentence1: A place of sorrow, after Pope John ...
# 2  rte  train  sentence1: Herceptin was already approved to t...
# 3  rte  train  sentence1: Judie Vivian, chief executive at Pr...
# 4  rte  train  sentence1: A man is due in court later charged...
#
#            target
# 0  not entailment
# 1      entailment
# 2      entailment
# 3      entailment
# 4  not entailment

# %% [markdown]
# ## WNLI Dataset
#
# The Winograd Schema Challenge (Levesque et al., 2011) is a reading comprehension task in which a system must read a sentence with a pronoun and select the referent of that pronoun from a list of choices. The examples are manually constructed to foil simple statistical methods: Each one is contingent on contextual information provided by a single word or phrase in the sentence. To convert the problem into sentence pair classification, the authors of the benchmark construct sentence pairs by replacing the ambiguous pronoun with each possible referent. The task is to predict if the sentence with the pronoun substituted is entailed by the original sentence. They use a small evaluation set consisting of new examples derived from fiction books that was shared privately by the authors of the original corpus. While the included training set is balanced between two classes, the test set is imbalanced between them (65% not entailment). Also, due to a data quirk, the development set is adversarial: hypotheses are sometimes shared between training and development examples, so if a model memorizes the training examples, they will predict the wrong label on corresponding development set example. As with QNLI, each example is evaluated separately, so there is not a systematic correspondence between a model's score on this task and its score on the unconverted original task. The authors of the benchmark call converted dataset WNLI (Winograd NLI).

# %%
wnli_dataset = load_dataset('glue', 'wnli')
# Out:
# ...
# Generating test split:   0%|          | 0/146 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/wnli/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
inputs = []
splits = []
targets = []

for split_label in ['train', 'test', 'validation']:
  split = wnli_dataset[split_label]
  for i in range(len(split)):
    this_entry = split[i]
    this_input = f"sentence1: {this_entry['sentence1']} sentence2: {this_entry['sentence2']}"
    this_target = 'test' if split_label == 'test' else 'entailment' if this_entry['label'] == 1 else 'not entailment'
    inputs.append(this_input)
    splits.append(split_label)
    targets.append(this_target)

wnli_df = pd.DataFrame({
    'task': 'wnli',
    'split': splits,
    'input': inputs,
    'target': targets,
})

# %%
wnli_df.head()
# Out:
#    task  split                                              input  \
# 0  wnli  train  sentence1: I stuck a pin through a carrot. Whe...
# 1  wnli  train  sentence1: John couldn't see the stage with Bi...
# 2  wnli  train  sentence1: The police arrested all of the gang...
# 3  wnli  train  sentence1: Steve follows Fred's example in eve...
# 4  wnli  train  sentence1: When Tatyana reached the cabin, her...
#
#            target
# 0      entailment
# 1      entailment
# 2      entailment
# 3  not entailment
# 4  not entailment

# %% [markdown]
# ## Combine All DataFrames

# %%
combined_df = pd.concat([cola_df,sst2_df, mrpc_df, qqp_df, stsb_df, mnli_df,
                         qnli_df, rte_df, wnli_df], axis=0, ignore_index=True)
combined_df.head()
# Out:
#    task  split                                              input      target
# 0  cola  train  sentence: Our friends won't buy this analysis,...  acceptable
# 1  cola  train  sentence: One more pseudo generalization and I...  acceptable
# 2  cola  train  sentence: One more pseudo generalization or I'...  acceptable
# 3  cola  train  sentence: The more we study verbs, the crazier...  acceptable
# 4  cola  train  sentence: Day by day the facts are getting mur...  acceptable

# %%
combined_dataset = Dataset.from_pandas(combined_df)
combined_dataset.push_to_hub("hanmaegeo/glue_text_to_text")
# Out:
# ...
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
